# %%
import yt

# %%
ds = yt.load("BR2D_stripes_0040.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-03-29 09:45:32,392 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-03-29 09:45:32,393 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-03-29 09:45:32,403 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-03-29 09:45:32,406 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-03-29 09:45:32,408 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"v")
#p.annotate_cell_edges()
p.annotate_grids()
p.show()
p.save("testt.png")
# Out:
# yt : [WARNING  ] 2022-03-29 09:45:35,473 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-03-29 09:45:36,279 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-03-29 09:45:36,280 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-03-29 09:45:36,282 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-03-29 09:45:36,282 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-03-29 09:45:36,286 Making a fixed resolution buffer of (('amrvac', 'v')) 800 by 800
# C:\Users\gebruiker\AppData\Local\Programs\Python\Python38-32\lib\site-packages\unyt\array.py:1778: RuntimeWarning: invalid value encountered in true_divide
#   out_arr = func(
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-03-29 09:45:37,569 Saving plot testt.png
# ['testt.png']

# %%
ds.field_list
# Out:
# [('amrvac', 'u'), ('amrvac', 'v')]
