# %%
import yt

# %%
ds = yt.load("BR2D_stripes_0000.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-04-21 18:34:46,511 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-04-21 18:34:46,512 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-21 18:34:46,515 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-21 18:34:46,518 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-04-21 18:34:46,520 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
# Out:
# yt : [INFO     ] 2022-04-21 22:36:43,038 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 22:36:43,040 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 22:36:43,043 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 22:36:43,049 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 22:36:43,053 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds.field_list
# Out:
# [('amrvac', 'u'), ('amrvac', 'v')]

# %%
ds = yt.load("BR2D_stripes_0040.dat", unit_system="code")
p=yt.plot_2d(ds,"u")
p.show()
# Out:
# yt : [INFO     ] 2022-04-22 01:01:46,237 Parameters: current_time              = 200.0
# yt : [INFO     ] 2022-04-22 01:01:46,239 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-22 01:01:46,241 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-22 01:01:46,243 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-04-22 01:01:46,246 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-04-22 01:01:46,297 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-22 01:01:47,990 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-22 01:01:47,994 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-22 01:01:48,003 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-22 01:01:48,005 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-22 01:01:48,010 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
