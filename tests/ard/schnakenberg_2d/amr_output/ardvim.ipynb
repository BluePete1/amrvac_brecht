# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = yt.load("nonlin_refres_amr3_0000.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-06-07 22:20:42,137 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-06-07 22:20:42,139 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2022-06-07 22:20:42,144 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-07 22:20:42,146 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-07 22:20:42,147 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
# Out:
# yt : [WARNING  ] 2022-06-07 22:20:43,613 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-06-07 22:20:44,357 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 22:20:44,360 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 22:20:44,363 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 22:20:44,364 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 22:20:44,366 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds1 = yt.load("nonlin1_amr4_0010.dat", unit_system="code")
ds2 = yt.load("nonlin2_amr4_0010.dat", unit_system="code")

p1=yt.plot_2d(ds1,"u")
p2=yt.plot_2d(ds2,"u")
p1.set_log(("u"), False)
p2.set_log(("u"), False)
#p1.annotate_cell_edges()
#p2.annotate_cell_edges()
p1.annotate_grids()
p2.annotate_grids()
p1.set_xlabel("x")
p1.set_ylabel("y")
p2.set_xlabel("x")
p2.set_ylabel("y")
p1.show()
p2.show()

p1.save("grids1.png")
p2.save("grids2.png")
# Out:
# yt : [INFO     ] 2022-06-07 23:36:43,236 Parameters: current_time              = 0.000999999999999963
# yt : [INFO     ] 2022-06-07 23:36:43,238 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2022-06-07 23:36:43,240 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-07 23:36:43,241 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-07 23:36:43,243 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-06-07 23:36:43,411 Parameters: current_time              = 0.009999999999999386
# yt : [INFO     ] 2022-06-07 23:36:43,414 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2022-06-07 23:36:43,415 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-07 23:36:43,419 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-07 23:36:43,420 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-06-07 23:36:43,520 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-06-07 23:36:44,347 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:44,347 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:44,349 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:44,350 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:44,355 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# yt : [WARNING  ] 2022-06-07 23:36:44,625 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-06-07 23:36:45,360 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:45,362 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:45,364 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:45,366 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-07 23:36:45,370 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-06-07 23:36:46,744 Saving plot grids1.png
# yt : [INFO     ] 2022-06-07 23:36:46,984 Saving plot grids2.png
# ['grids2.png']

# %%
ds = yt.load("nonlin_mpi_128_0010.dat", unit_system="code")

p=yt.plot_2d(ds,"u")
p.set_log(("u"), False)
#p.annotate_cell_edges()
#p.annotate_grids()
p.set_xlabel("x")
p.set_ylabel("y")
p.show()

p.save("mpaai.png")
# Out:
# yt : [INFO     ] 2022-06-08 00:49:04,142 Parameters: current_time              = 1.0
# yt : [INFO     ] 2022-06-08 00:49:04,143 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-06-08 00:49:04,145 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-08 00:49:04,146 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-08 00:49:04,148 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-06-08 00:49:04,180 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-06-08 00:49:05,054 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-08 00:49:05,056 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-08 00:49:05,059 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-08 00:49:05,060 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-06-08 00:49:05,063 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-06-08 00:49:05,619 Saving plot mpaai.png
# ['mpaai.png']

# %%
field = ("u")  # The field to average
weight = ("u")  # The weight for the average

ad = ds.all_data()  # This is a region describing the entire box,
# but note it doesn't read anything in yet!

# We now use our 'quantities' call to get the average quantity
average_value = ad.quantities.weighted_average_quantity(field, weight)

print("Average %s (weighted by %s) is %0.3e %s" % (field, weight, average_value, average_value.units))

#print(
#    "Average %s (weighted by %s) is %0.3e %s"
#    % (field[1], weight[1], average_value, average_value.units)
#)
# Out:
# Average u (weighted by u) is 9.001e-01 dimensionless

# %%
# Say we interpolate to AMR level 1
level = 0
rawdata = ds.covering_grid(level, left_edge=ds.domain_left_edge, 
                          dims=ds.domain_dimensions * ds.refine_by**level)['u']

# %%
# now you can for instance create a matplotlib figure and plot the data, or do other stuff with it
fig, ax = plt.subplots(1)
density = rawdata[:, :, 0].value
# rotate 90 degrees counterclockwise due to imshow's convention of the origin (top-left)
ax.imshow(np.rot90(np.log10(density)))  
plt.show()

# %%
print(rawdata[:, :, 0].value)

#rho_l4[:, :, 0].value
#sum(rho_l4[:, :, 0].value)
#sum((rho_l4[:, :, 0].value)**2)
# Out:
# [[0.9 0.9 0.9 ... 0.9 0.9 0.9]
#  [0.9 0.9 0.9 ... 0.9 0.9 0.9]
#  [0.9 0.9 0.9 ... 0.9 0.9 0.9]
#  ...
#  [0.9 0.9 0.9 ... 0.9 0.9 0.9]
#  [0.9 0.9 0.9 ... 0.9 0.9 0.9]
#  [0.9 0.9 0.9 ... 0.9 0.9 0.9]]

# %%
ad = ds.all_data()
print(ad.sum(("u")))
print(f"{ad.max_level=}, {ad.min_level=}")
ad.max_level = ad.min_level = 2
print(f"{ad.max_level=}, {ad.min_level=}")
print(ad.sum(("u")))
# Out:
# 58988.57577856904 dimensionless
# ad.max_level=0, ad.min_level=0
# ad.max_level=2, ad.min_level=2
# 0.0 dimensionless
