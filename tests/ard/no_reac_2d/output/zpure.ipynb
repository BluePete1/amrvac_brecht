# %%
import yt

n = "100"
ds1 = yt.load("pure_adv_0"+ n +".dat", unit_system="code")
ds2 = yt.load("pure_adv2_0" + n + ".dat", unit_system="code")

p1=yt.plot_2d(ds1,"u")
p2=yt.plot_2d(ds2,"u")
#p1.annotate_cell_edges()
#p2.annotate_cell_edges()
p1.annotate_grids()
p2.annotate_grids()
p1.set_xlabel("x")
p1.set_ylabel("y")
p2.set_xlabel("x")
p2.set_ylabel("y")
p1.show()
p2.show()

#p1.save("GSD" + n + ".png")
#p2.save("GSAD" + n + ".png")
# Out:
# yt : [INFO     ] 2022-05-02 02:09:36,332 Parameters: current_time              = 2.0
# yt : [INFO     ] 2022-05-02 02:09:36,334 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-05-02 02:09:36,338 Parameters: domain_left_edge          = [-4. -4.  0.]
# yt : [INFO     ] 2022-05-02 02:09:36,342 Parameters: domain_right_edge         = [4. 4. 1.]
# yt : [INFO     ] 2022-05-02 02:09:36,343 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-05-02 02:09:36,483 Parameters: current_time              = 2.0
# yt : [INFO     ] 2022-05-02 02:09:36,486 Parameters: domain_dimensions         = [1024 1024    1]
# yt : [INFO     ] 2022-05-02 02:09:36,489 Parameters: domain_left_edge          = [-4. -4.  0.]
# yt : [INFO     ] 2022-05-02 02:09:36,491 Parameters: domain_right_edge         = [4. 4. 1.]
# yt : [INFO     ] 2022-05-02 02:09:36,492 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-05-02 02:09:36,668 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-05-02 02:09:37,727 xlim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:37,728 ylim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:37,730 xlim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:37,731 ylim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:37,735 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# yt : [WARNING  ] 2022-05-02 02:09:39,374 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-05-02 02:09:41,395 xlim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:41,396 ylim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:41,398 xlim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:41,400 ylim = -4.000000 4.000000
# yt : [INFO     ] 2022-05-02 02:09:41,403 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# C:\Users\gebruiker\AppData\Local\Programs\Python\Python38-32\lib\site-packages\unyt\array.py:1778: RuntimeWarning: invalid value encountered in true_divide
#   out_arr = func(
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
