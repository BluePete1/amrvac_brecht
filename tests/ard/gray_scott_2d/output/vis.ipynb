# %%
import yt

# %%
ds = yt.load("wmaze_amr_0040.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-04-08 09:57:46,307 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-04-08 09:57:46,309 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-08 09:57:46,315 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-08 09:57:46,318 Parameters: domain_right_edge         = [2. 2. 1.]
# yt : [INFO     ] 2022-04-08 09:57:46,319 Parameters: cosmological_simulation   = 0

# %%
ds.field_list
# Out:
# yt : [WARNING  ] 2022-04-07 16:34:13,924 e not found and no parfile passed, can not set thermal_pressure.
# [('amrvac', 'u'), ('amrvac', 'v')]

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
p.annotate_grids()
p.show()
#p.save("testt.png")
# Out:
# yt : [WARNING  ] 2022-04-08 09:57:56,955 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-08 09:57:59,721 xlim = 0.000000 2.000000
# yt : [INFO     ] 2022-04-08 09:57:59,722 ylim = 0.000000 2.000000
# yt : [INFO     ] 2022-04-08 09:57:59,726 xlim = 0.000000 2.000000
# yt : [INFO     ] 2022-04-08 09:57:59,731 ylim = 0.000000 2.000000
# yt : [INFO     ] 2022-04-08 09:57:59,733 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
