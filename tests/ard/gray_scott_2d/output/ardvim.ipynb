# %%
import yt

# %%
ds = yt.load("maze2_2048_0004.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-05-17 17:14:12,951 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-05-17 17:14:12,953 Parameters: domain_dimensions         = [2048 2048    1]
# yt : [INFO     ] 2022-05-17 17:14:12,955 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-17 17:14:12,959 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-05-17 17:14:12,961 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
# Out:
# yt : [WARNING  ] 2022-05-17 17:14:22,254 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-05-17 17:14:31,404 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-05-17 17:14:31,404 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-05-17 17:14:31,406 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-05-17 17:14:31,408 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-05-17 17:14:31,411 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
n = "40"
ds1 = yt.load("maze_128_00"+ n +".dat", unit_system="code")
ds2 = yt.load("maze_adv_128_00" + n + ".dat", unit_system="code")

p1=yt.plot_2d(ds1,"u")
p2=yt.plot_2d(ds2,"u")
p1.set_xlabel("x")
p1.set_ylabel("y")
p2.set_xlabel("x")
p2.set_ylabel("y")
p1.show()
p2.show()

p1.save("GSD" + n + ".png")
p2.save("GSAD" + n + ".png")
# Out:
# yt : [INFO     ] 2022-05-02 02:42:55,075 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-05-02 02:42:55,077 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-05-02 02:42:55,081 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-02 02:42:55,083 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-05-02 02:42:55,084 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-05-02 02:42:55,235 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-05-02 02:42:55,236 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-05-02 02:42:55,238 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-05-02 02:42:55,240 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-05-02 02:42:55,241 Parameters: cosmological_simulation   = 0
# ...
