# %%
import yt

# %%
ds = yt.load("maze_amr_0040.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-04-22 01:59:19,003 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-04-22 01:59:19,005 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-22 01:59:19,006 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-22 01:59:19,010 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-04-22 01:59:19,012 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
# Out:
# yt : [WARNING  ] 2022-04-22 01:59:22,155 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-22 01:59:25,129 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 01:59:25,131 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 01:59:25,134 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 01:59:25,135 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 01:59:25,144 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
n = "40"
ds1 = yt.load("maze_128_00"+ n +".dat", unit_system="code")
ds2 = yt.load("maze_adv_128_00" + n + ".dat", unit_system="code")

p1=yt.plot_2d(ds1,"u")
p2=yt.plot_2d(ds2,"u")
p1.set_xlabel("x")
p1.set_ylabel("y")
p2.set_xlabel("x")
p2.set_ylabel("y")
p1.show()
p2.show()

p1.save("GSD" + n + ".png")
p2.save("GSAD" + n + ".png")
# Out:
# yt : [INFO     ] 2022-04-22 22:36:03,060 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-04-22 22:36:03,061 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-22 22:36:03,063 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-22 22:36:03,065 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-04-22 22:36:03,067 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-04-22 22:36:03,175 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2022-04-22 22:36:03,176 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-22 22:36:03,177 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-22 22:36:03,178 Parameters: domain_right_edge         = [2.5 2.5 1. ]
# yt : [INFO     ] 2022-04-22 22:36:03,181 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-04-22 22:36:03,221 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-22 22:36:03,838 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:03,839 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:03,842 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:03,844 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:03,847 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# yt : [WARNING  ] 2022-04-22 22:36:04,120 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-22 22:36:04,947 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:04,948 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:04,954 xlim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:04,957 ylim = 0.000000 2.500000
# yt : [INFO     ] 2022-04-22 22:36:04,960 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-04-22 22:36:06,205 Saving plot GSD40.png
# yt : [INFO     ] 2022-04-22 22:36:06,462 Saving plot GSAD40.png
# ['GSAD40.png']
