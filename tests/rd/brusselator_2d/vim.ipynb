# %%
import yt

# %%
ds = yt.load("BR2D_stripes_0040.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-04-14 09:07:07,066 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-04-14 09:07:07,071 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-14 09:07:07,073 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-14 09:07:07,074 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-04-14 09:07:07,076 Parameters: cosmological_simulation   = 0

# %%
ds.field_list
# Out:
# [('amrvac', 'u'), ('amrvac', 'v')]

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
#p.save("testt.png")
# Out:
# yt : [WARNING  ] 2022-04-14 09:07:09,260 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-14 09:07:10,108 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-14 09:07:10,109 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-14 09:07:10,111 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-14 09:07:10,112 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-14 09:07:10,116 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
