# %%
import yt

# %%
ds = yt.load("BR2D_stripes_0000.dat", unit_system="code")
# Out:
# yt : [INFO     ] 2022-04-21 18:44:27,975 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-04-21 18:44:27,978 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-21 18:44:27,981 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-21 18:44:27,985 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-04-21 18:44:27,990 Parameters: cosmological_simulation   = 0

# %%
#ds.covering_grid() #Data in matrix uit dat file halen
p=yt.plot_2d(ds,"u")
#p.annotate_cell_edges()
#p.annotate_grids()
p.show()
# Out:
# yt : [WARNING  ] 2022-04-21 18:44:33,066 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-21 18:44:34,546 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:34,549 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:34,553 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:34,555 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:34,558 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds = yt.load("BR2D_stripes_0040.dat", unit_system="code")
p=yt.plot_2d(ds,"u")
p.show()
# Out:
# yt : [INFO     ] 2022-04-21 18:44:56,758 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-04-21 18:44:56,761 Parameters: domain_dimensions         = [128 128   1]
# yt : [INFO     ] 2022-04-21 18:44:56,765 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-04-21 18:44:56,769 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2022-04-21 18:44:56,771 Parameters: cosmological_simulation   = 0
# yt : [WARNING  ] 2022-04-21 18:44:56,856 e not found and no parfile passed, can not set thermal_pressure.
# yt : [INFO     ] 2022-04-21 18:44:58,158 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:58,160 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:58,167 xlim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:58,170 ylim = 0.000000 64.000000
# yt : [INFO     ] 2022-04-21 18:44:58,177 Making a fixed resolution buffer of (('amrvac', 'u')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
